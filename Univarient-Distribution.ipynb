# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %% [markdown]
# Importing Modules

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
pollution_data = pd.read_csv('./Dataset/global air pollution dataset.csv')

# %%
pollution_data.head()
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2               Italy   Priolo Gargallo         66     Moderate             1
# 3              Poland         Przasnysz         34         Good             1
# 4              France          Punaauia         22         Good             0
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good               39               Good              2
# 3            Good               34               Good              0
# 4            Good               22               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# ...

# %%
sns.histplot(pollution_data['AQI Value'])
# Out:
# <Axes: xlabel='AQI Value', ylabel='Count'>

# %%
sns.displot(pollution_data['AQI Value'])

# %%
sns.distplot(pollution_data['AQI Value'])
# Out:
# <Axes: xlabel='AQI Value', ylabel='Density'>
